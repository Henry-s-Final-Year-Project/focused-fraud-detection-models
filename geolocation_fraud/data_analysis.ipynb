# %% [markdown]
# ## Geolocation Fraud Detection Model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
)
import joblib
import shap
import os
from imblearn.metrics import geometric_mean_score

# %%
import google.colab as colab
colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/FYP_model_assets/geolocation_fraud_dataset.csv')

# %%
df
# Out:
#         transaction_id                   timestamp  amount currency  \
# 0                17267  2025-01-28 00:34:00.291206  261.11      JPY
# 1                90569  2025-02-08 23:20:06.875266   21.57      EUR
# 2                20959  2025-01-01 10:28:07.661918   80.73      GBP
# 3                 7776  2025-01-02 10:24:46.009232   79.32      EUR
# 4               123935  2025-02-26 08:38:37.398943   40.37      JPY
# ...                ...                         ...     ...      ...
# 199995          143487  2025-03-05 13:47:49.978166   13.58      EUR
# 199996           80492  2025-03-04 15:09:54.342152   10.71      JPY
# 199997          194191  2025-02-20 04:54:46.799870   47.58      EUR
# 199998           71976  2025-02-28 03:02:05.570887  228.48      JPY
# 199999          108126  2025-01-11 00:06:41.738495   33.60      USD
#
#        transaction_type country             city   latitude   longitude  \
# 0              PURCHASE      TR      Hallchester        NaN  131.475327
# 1            WITHDRAWAL      US  Port Lindaville  71.108646   67.911829
# 2              PURCHASE      PS     Shawnborough        NaN   41.949825
# 3              TRANSFER      MH  East Jeffreyton        NaN    9.634126
# 4              TRANSFER      BY      Kaitlynbury  47.217326         NaN
# ...                 ...     ...              ...        ...         ...
# 199995         TRANSFER      OM      Deborahland -48.743021         NaN
# 199996         TRANSFER      CG        New Kevin -85.094167 -175.531951
# 199997         PURCHASE      KI   Lake Kevinberg -10.462643   63.912476
# 199998         TRANSFER      BJ      Williamberg -13.197699         NaN
# 199999         TRANSFER      MD       Robertstad        NaN -125.134650
#
#              ip_address  ... transactions_last_7d  time_since_last_login  \
# 0        104.252.129.91  ...                    7                   79.5
# 1        141.155.161.25  ...                    5                   45.5
# 2         20.229.90.101  ...                   12                   45.7
# 3       138.187.225.190  ...                    6                   83.2
# 4       154.148.213.129  ...                    7                   32.6
# ...                 ...  ...                  ...                    ...
# 199995   167.186.84.217  ...                    6                  165.6
# 199996    208.74.235.19  ...                   12                   15.1
# 199997  121.188.232.206  ...                    8                   66.9
# 199998    75.112.85.144  ...                    4                    4.4
# 199999   211.245.165.94  ...                    7                   49.7
#
#        login_attempts_last_24h is_new_device vpn_usage proxy_usage  \
# 0                            3             0         1           1
# 1                            1             0         0           0
# 2                            5             0         0           0
# 3                            5             0         0           0
# 4                            2             0         0           0
# ...                        ...           ...       ...         ...
# 199995                       5             0         0           0
# 199996                       3             0         0           0
# 199997                       0             0         0           0
# 199998                       4             0         0           0
# 199999                       3             0         0           0
#
#        ip_risk_score    ASN                          ISP  is_fraud
# 0                 11  72572  Garcia, Mueller and Collins         0
# 1                 36  31015    Stewart, Banks and Harvey         0
# 2                 29  71203             Thomas-Rodriguez         0
# 3                 34  88766                Powell-Brooks         0
# 4                 30  90183                  Reed-Wilson         0
# ...              ...    ...                          ...       ...
# 199995            66  33814                     Cook PLC         0
# 199996            45  99696                Williams-Vega         0
# 199997            51  19939               Hughes-Winters         0
# 199998            46  19483                   Austin Ltd         0
# 199999            51  66482                  Wilkins LLC         0
#
# [200000 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# transaction_id                 0
# timestamp                      0
# amount                         0
# currency                       0
# transaction_type               0
# country                      990
# city                           0
# latitude                   39969
# longitude                  39813
# ip_address                     0
# timezone                       0
# user_id                        0
# device_id                  20129
# device_type                    0
# operating_system               0
# app_version                    0
# user_agent                     0
# avg_spend_30d              30027
# transactions_last_7d           0
# time_since_last_login          0
# login_attempts_last_24h        0
# is_new_device                  0
# vpn_usage                      0
# proxy_usage                    0
# ip_risk_score                  0
# ASN                            0
# ISP                            0
# is_fraud                       0
# dtype: int64

# %% [markdown]
# #### Data Preprocessing

# %%
drop_cols = ['transaction_id', 'timestamp', 'device_id', 'ip_address', 'user_id', 'user_agent', 'city']
df.drop(columns=drop_cols, inplace=True)

# %%
df.head(5)
# Out:
#    amount currency transaction_type country   latitude   longitude  \
# 0  261.11      JPY         PURCHASE      TR        NaN  131.475327
# 1   21.57      EUR       WITHDRAWAL      US  71.108646   67.911829
# 2   80.73      GBP         PURCHASE      PS        NaN   41.949825
# 3   79.32      EUR         TRANSFER      MH        NaN    9.634126
# 4   40.37      JPY         TRANSFER      BY  47.217326         NaN
#
#             timezone device_type operating_system app_version  ...  \
# 0  Europe/Luxembourg     Desktop              iOS       6.8.3  ...
# 1    Africa/Khartoum      Mobile              iOS       5.0.5  ...
# 2        Asia/Taipei      Mobile          Windows       5.9.4  ...
# 3          Asia/Aden     Desktop          Android       2.1.8  ...
# 4    Europe/Helsinki      Mobile          Windows       4.0.4  ...
#
#    transactions_last_7d  time_since_last_login  login_attempts_last_24h  \
# 0                     7                   79.5                        3
# 1                     5                   45.5                        1
# 2                    12                   45.7                        5
# 3                     6                   83.2                        5
# 4                     7                   32.6                        2
#
#    is_new_device  vpn_usage  proxy_usage  ip_risk_score    ASN  \
# 0              0          1            1             11  72572
# 1              0          0            0             36  31015
# 2              0          0            0             29  71203
# 3              0          0            0             34  88766
# 4              0          0            0             30  90183
#
#                            ISP is_fraud
# 0  Garcia, Mueller and Collins        0
# 1    Stewart, Banks and Harvey        0
# 2             Thomas-Rodriguez        0
# 3                Powell-Brooks        0
# 4                  Reed-Wilson        0
#
# [5 rows x 21 columns]

# %% [markdown]
# These fields are either:
# - Not available during real-time inference (e.g., transaction_id)
# - Too high-cardinality for tree models (ip_address, user_agent)
# - Not adding predictive value or cause input bloat in Triton

# %% [markdown]
# #### Label and Feature Separation

# %%
target_col = "is_fraud"
binary_cols = ['vpn_usage', 'proxy_usage', 'is_new_device']
categorical_cols = [
    'currency', 'transaction_type', 'country', 'device_type',
    'operating_system', 'app_version', 'timezone', 'ISP'
]
numeric_cols = [
    'amount', 'avg_spend_30d', 'transactions_last_7d',
    'time_since_last_login', 'login_attempts_last_24h',
    'ip_risk_score', 'latitude', 'longitude', 'ASN'
]

# %% [markdown]
# #### Imputation and Encoding

# %%
num_imputer = SimpleImputer(strategy='median')
df[numeric_cols] = num_imputer.fit_transform(df[numeric_cols])

df['country'] = df['country'].fillna("missing")

# %% [markdown]
# - Median imputation is robust to outliers and common for fraud datasets (due to skewed features like amount).
# - Keeps the numerical shape consistent for Triton inference.

# %%
df[binary_cols] = df[binary_cols].astype(int)

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df[categorical_cols] = ordinal_encoder.fit_transform(df[categorical_cols])

# %%
# print type of each column for df
print(df.dtypes)
# Out:
# amount                     float64
# currency                   float64
# transaction_type           float64
# country                    float64
# latitude                   float64
# longitude                  float64
# timezone                   float64
# device_type                float64
# operating_system           float64
# app_version                float64
# avg_spend_30d              float64
# transactions_last_7d       float64
# time_since_last_login      float64
# login_attempts_last_24h    float64
# is_new_device                int64
# vpn_usage                    int64
# proxy_usage                  int64
# ip_risk_score              float64
# ASN                        float64
# ISP                        float64
# is_fraud                     int64
# dtype: object

# %% [markdown]
# 1. Label/Ordinal Encoding is better for XGBoost, which handles category splits natively.
# 2. One-hot encoding causes dimensionality explosion, unnecessary with tree models.
# 3. Triton expects fixed input shape, so we avoid sparse/dynamic one-hot formats.

# %%
X = df.drop(columns=[target_col])
y = df[target_col]

# %%
del(df)

# %% [markdown]
# #### Train Test Split

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# %% [markdown]
# #### Model Training

# %%
from xgboost import XGBClassifier

scale_pos_weight = (len(y_train) - sum(y_train)) / sum(y_train)

model = XGBClassifier(
    objective="binary:logistic",
    eval_metric="auc",
    use_label_encoder=False,
    max_depth=6,
    learning_rate=0.05,
    n_estimators=500,
    scale_pos_weight=scale_pos_weight,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)
# Out:
# [0]	validation_0-auc:0.76367
# [1]	validation_0-auc:0.86896
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [22:45:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [2]	validation_0-auc:0.90055
# [3]	validation_0-auc:0.90532
# [4]	validation_0-auc:0.90216
# [5]	validation_0-auc:0.90413
# [6]	validation_0-auc:0.90524
# [7]	validation_0-auc:0.90470
# [8]	validation_0-auc:0.90530
# [9]	validation_0-auc:0.90573
# [10]	validation_0-auc:0.90654
# [11]	validation_0-auc:0.90670
# [12]	validation_0-auc:0.90649
# [13]	validation_0-auc:0.90689
# [14]	validation_0-auc:0.90632
# [15]	validation_0-auc:0.90709
# [16]	validation_0-auc:0.90734
# [17]	validation_0-auc:0.90759
# [18]	validation_0-auc:0.90866
# [19]	validation_0-auc:0.90868
# [20]	validation_0-auc:0.90869
# [21]	validation_0-auc:0.90899
# [22]	validation_0-auc:0.90898
# [23]	validation_0-auc:0.90872
# [24]	validation_0-auc:0.90835
# [25]	validation_0-auc:0.90846
# [26]	validation_0-auc:0.90866
# [27]	validation_0-auc:0.90866
# [28]	validation_0-auc:0.90886
# [29]	validation_0-auc:0.90877
# [30]	validation_0-auc:0.90841
# [31]	validation_0-auc:0.90853
# [32]	validation_0-auc:0.90856
# [33]	validation_0-auc:0.90857
# [34]	validation_0-auc:0.90884
# [35]	validation_0-auc:0.90898
# [36]	validation_0-auc:0.90921
# [37]	validation_0-auc:0.90926
# [38]	validation_0-auc:0.90947
# [39]	validation_0-auc:0.90958
# [40]	validation_0-auc:0.90952
# [41]	validation_0-auc:0.90947
# [42]	validation_0-auc:0.90943
# [43]	validation_0-auc:0.90936
# [44]	validation_0-auc:0.90952
# [45]	validation_0-auc:0.90990
# [46]	validation_0-auc:0.91001
# [47]	validation_0-auc:0.90982
# [48]	validation_0-auc:0.90980
# [49]	validation_0-auc:0.90993
# [50]	validation_0-auc:0.91006
# [51]	validation_0-auc:0.91017
# [52]	validation_0-auc:0.91016
# [53]	validation_0-auc:0.91018
# [54]	validation_0-auc:0.91003
# [55]	validation_0-auc:0.91013
# [56]	validation_0-auc:0.91009
# [57]	validation_0-auc:0.91010
# [58]	validation_0-auc:0.91021
# [59]	validation_0-auc:0.91022
# [60]	validation_0-auc:0.91015
# [61]	validation_0-auc:0.91016
# [62]	validation_0-auc:0.91009
# [63]	validation_0-auc:0.91007
# [64]	validation_0-auc:0.91005
# [65]	validation_0-auc:0.91008
# [66]	validation_0-auc:0.91015
# [67]	validation_0-auc:0.91031
# [68]	validation_0-auc:0.91023
# [69]	validation_0-auc:0.91026
# [70]	validation_0-auc:0.91012
# [71]	validation_0-auc:0.91004
# [72]	validation_0-auc:0.90993
# [73]	validation_0-auc:0.91007
# [74]	validation_0-auc:0.91003
# [75]	validation_0-auc:0.91005
# [76]	validation_0-auc:0.91017
# [77]	validation_0-auc:0.91015
# [78]	validation_0-auc:0.91012
# [79]	validation_0-auc:0.91008
# [80]	validation_0-auc:0.91012
# [81]	validation_0-auc:0.91013
# [82]	validation_0-auc:0.91015
# [83]	validation_0-auc:0.91009
# [84]	validation_0-auc:0.91011
# [85]	validation_0-auc:0.91011
# [86]	validation_0-auc:0.91015
# [87]	validation_0-auc:0.91010
# [88]	validation_0-auc:0.91014
# [89]	validation_0-auc:0.91011
# [90]	validation_0-auc:0.91020
# [91]	validation_0-auc:0.91020
# [92]	validation_0-auc:0.91019
# [93]	validation_0-auc:0.91020
# [94]	validation_0-auc:0.91040
# [95]	validation_0-auc:0.91036
# [96]	validation_0-auc:0.91036
# [97]	validation_0-auc:0.91041
# [98]	validation_0-auc:0.91021
# [99]	validation_0-auc:0.91035
# [100]	validation_0-auc:0.91046
# [101]	validation_0-auc:0.91058
# [102]	validation_0-auc:0.91053
# [103]	validation_0-auc:0.91077
# [104]	validation_0-auc:0.91077
# [105]	validation_0-auc:0.91086
# [106]	validation_0-auc:0.91085
# [107]	validation_0-auc:0.91092
# [108]	validation_0-auc:0.91089
# [109]	validation_0-auc:0.91092
# [110]	validation_0-auc:0.91087
# [111]	validation_0-auc:0.91088
# [112]	validation_0-auc:0.91084
# [113]	validation_0-auc:0.91080
# [114]	validation_0-auc:0.91074
# [115]	validation_0-auc:0.91076
# [116]	validation_0-auc:0.91080
# [117]	validation_0-auc:0.91073
# [118]	validation_0-auc:0.91059
# [119]	validation_0-auc:0.91069
# [120]	validation_0-auc:0.91063
# [121]	validation_0-auc:0.91059
# [122]	validation_0-auc:0.91069
# [123]	validation_0-auc:0.91063
# [124]	validation_0-auc:0.91055
# [125]	validation_0-auc:0.91031
# [126]	validation_0-auc:0.91027
# [127]	validation_0-auc:0.91023
# [128]	validation_0-auc:0.91004
# [129]	validation_0-auc:0.91004
# [130]	validation_0-auc:0.90991
# [131]	validation_0-auc:0.90984
# [132]	validation_0-auc:0.90988
# [133]	validation_0-auc:0.90982
# [134]	validation_0-auc:0.90982
# [135]	validation_0-auc:0.90972
# [136]	validation_0-auc:0.90965
# [137]	validation_0-auc:0.90958
# [138]	validation_0-auc:0.90956
# [139]	validation_0-auc:0.90955
# [140]	validation_0-auc:0.90963
# [141]	validation_0-auc:0.90968
# [142]	validation_0-auc:0.90970
# [143]	validation_0-auc:0.90967
# [144]	validation_0-auc:0.90966
# [145]	validation_0-auc:0.90971
# [146]	validation_0-auc:0.90976
# [147]	validation_0-auc:0.90971
# [148]	validation_0-auc:0.90976
# [149]	validation_0-auc:0.90972
# [150]	validation_0-auc:0.90965
# [151]	validation_0-auc:0.90966
# [152]	validation_0-auc:0.90972
# [153]	validation_0-auc:0.90969
# [154]	validation_0-auc:0.90975
# [155]	validation_0-auc:0.90976
# [156]	validation_0-auc:0.90982
# [157]	validation_0-auc:0.90983
# [158]	validation_0-auc:0.90983
# [159]	validation_0-auc:0.90983
# [160]	validation_0-auc:0.90977
# [161]	validation_0-auc:0.90964
# [162]	validation_0-auc:0.90967
# [163]	validation_0-auc:0.90969
# [164]	validation_0-auc:0.90964
# [165]	validation_0-auc:0.90952
# [166]	validation_0-auc:0.90951
# [167]	validation_0-auc:0.90949
# [168]	validation_0-auc:0.90944
# [169]	validation_0-auc:0.90944
# [170]	validation_0-auc:0.90942
# [171]	validation_0-auc:0.90933
# [172]	validation_0-auc:0.90938
# [173]	validation_0-auc:0.90939
# [174]	validation_0-auc:0.90937
# [175]	validation_0-auc:0.90932
# [176]	validation_0-auc:0.90928
# [177]	validation_0-auc:0.90919
# [178]	validation_0-auc:0.90914
# [179]	validation_0-auc:0.90916
# [180]	validation_0-auc:0.90904
# [181]	validation_0-auc:0.90896
# [182]	validation_0-auc:0.90886
# [183]	validation_0-auc:0.90887
# [184]	validation_0-auc:0.90882
# [185]	validation_0-auc:0.90881
# [186]	validation_0-auc:0.90876
# [187]	validation_0-auc:0.90877
# [188]	validation_0-auc:0.90878
# [189]	validation_0-auc:0.90880
# [190]	validation_0-auc:0.90884
# [191]	validation_0-auc:0.90887
# [192]	validation_0-auc:0.90881
# [193]	validation_0-auc:0.90886
# [194]	validation_0-auc:0.90886
# [195]	validation_0-auc:0.90880
# [196]	validation_0-auc:0.90872
# [197]	validation_0-auc:0.90872
# [198]	validation_0-auc:0.90871
# [199]	validation_0-auc:0.90867
# [200]	validation_0-auc:0.90862
# [201]	validation_0-auc:0.90860
# [202]	validation_0-auc:0.90862
# [203]	validation_0-auc:0.90861
# [204]	validation_0-auc:0.90855
# [205]	validation_0-auc:0.90865
# [206]	validation_0-auc:0.90863
# [207]	validation_0-auc:0.90859
# [208]	validation_0-auc:0.90856
# [209]	validation_0-auc:0.90853
# [210]	validation_0-auc:0.90856
# [211]	validation_0-auc:0.90843
# [212]	validation_0-auc:0.90838
# [213]	validation_0-auc:0.90834
# [214]	validation_0-auc:0.90836
# [215]	validation_0-auc:0.90833
# [216]	validation_0-auc:0.90829
# [217]	validation_0-auc:0.90825
# [218]	validation_0-auc:0.90831
# [219]	validation_0-auc:0.90828
# [220]	validation_0-auc:0.90832
# [221]	validation_0-auc:0.90823
# [222]	validation_0-auc:0.90818
# [223]	validation_0-auc:0.90818
# [224]	validation_0-auc:0.90810
# [225]	validation_0-auc:0.90807
# [226]	validation_0-auc:0.90802
# [227]	validation_0-auc:0.90809
# [228]	validation_0-auc:0.90806
# [229]	validation_0-auc:0.90797
# [230]	validation_0-auc:0.90796
# [231]	validation_0-auc:0.90791
# [232]	validation_0-auc:0.90793
# [233]	validation_0-auc:0.90794
# [234]	validation_0-auc:0.90797
# [235]	validation_0-auc:0.90786
# [236]	validation_0-auc:0.90780
# [237]	validation_0-auc:0.90773
# [238]	validation_0-auc:0.90771
# [239]	validation_0-auc:0.90762
# [240]	validation_0-auc:0.90768
# [241]	validation_0-auc:0.90758
# [242]	validation_0-auc:0.90751
# [243]	validation_0-auc:0.90752
# [244]	validation_0-auc:0.90752
# [245]	validation_0-auc:0.90754
# [246]	validation_0-auc:0.90756
# [247]	validation_0-auc:0.90753
# [248]	validation_0-auc:0.90753
# [249]	validation_0-auc:0.90752
# [250]	validation_0-auc:0.90755
# [251]	validation_0-auc:0.90751
# [252]	validation_0-auc:0.90743
# [253]	validation_0-auc:0.90744
# [254]	validation_0-auc:0.90733
# [255]	validation_0-auc:0.90732
# [256]	validation_0-auc:0.90726
# [257]	validation_0-auc:0.90726
# [258]	validation_0-auc:0.90726
# [259]	validation_0-auc:0.90724
# [260]	validation_0-auc:0.90729
# [261]	validation_0-auc:0.90725
# [262]	validation_0-auc:0.90720
# [263]	validation_0-auc:0.90715
# [264]	validation_0-auc:0.90711
# [265]	validation_0-auc:0.90709
# [266]	validation_0-auc:0.90709
# [267]	validation_0-auc:0.90701
# [268]	validation_0-auc:0.90705
# [269]	validation_0-auc:0.90701
# [270]	validation_0-auc:0.90698
# [271]	validation_0-auc:0.90695
# [272]	validation_0-auc:0.90695
# [273]	validation_0-auc:0.90688
# [274]	validation_0-auc:0.90692
# [275]	validation_0-auc:0.90683
# [276]	validation_0-auc:0.90687
# [277]	validation_0-auc:0.90679
# [278]	validation_0-auc:0.90678
# [279]	validation_0-auc:0.90675
# [280]	validation_0-auc:0.90674
# [281]	validation_0-auc:0.90668
# [282]	validation_0-auc:0.90656
# [283]	validation_0-auc:0.90652
# [284]	validation_0-auc:0.90650
# [285]	validation_0-auc:0.90638
# [286]	validation_0-auc:0.90639
# [287]	validation_0-auc:0.90638
# [288]	validation_0-auc:0.90630
# [289]	validation_0-auc:0.90627
# [290]	validation_0-auc:0.90619
# [291]	validation_0-auc:0.90610
# [292]	validation_0-auc:0.90604
# [293]	validation_0-auc:0.90606
# [294]	validation_0-auc:0.90596
# [295]	validation_0-auc:0.90589
# [296]	validation_0-auc:0.90586
# [297]	validation_0-auc:0.90579
# [298]	validation_0-auc:0.90576
# [299]	validation_0-auc:0.90575
# [300]	validation_0-auc:0.90570
# [301]	validation_0-auc:0.90571
# [302]	validation_0-auc:0.90572
# [303]	validation_0-auc:0.90573
# [304]	validation_0-auc:0.90571
# [305]	validation_0-auc:0.90567
# [306]	validation_0-auc:0.90561
# [307]	validation_0-auc:0.90557
# [308]	validation_0-auc:0.90551
# [309]	validation_0-auc:0.90551
# [310]	validation_0-auc:0.90546
# [311]	validation_0-auc:0.90537
# [312]	validation_0-auc:0.90536
# [313]	validation_0-auc:0.90536
# [314]	validation_0-auc:0.90531
# [315]	validation_0-auc:0.90524
# [316]	validation_0-auc:0.90522
# [317]	validation_0-auc:0.90522
# [318]	validation_0-auc:0.90522
# [319]	validation_0-auc:0.90518
# [320]	validation_0-auc:0.90527
# [321]	validation_0-auc:0.90517
# [322]	validation_0-auc:0.90514
# [323]	validation_0-auc:0.90510
# [324]	validation_0-auc:0.90505
# [325]	validation_0-auc:0.90507
# [326]	validation_0-auc:0.90494
# [327]	validation_0-auc:0.90485
# [328]	validation_0-auc:0.90487
# [329]	validation_0-auc:0.90483
# [330]	validation_0-auc:0.90484
# [331]	validation_0-auc:0.90486
# [332]	validation_0-auc:0.90479
# [333]	validation_0-auc:0.90476
# [334]	validation_0-auc:0.90473
# [335]	validation_0-auc:0.90472
# [336]	validation_0-auc:0.90470
# [337]	validation_0-auc:0.90467
# [338]	validation_0-auc:0.90467
# [339]	validation_0-auc:0.90472
# [340]	validation_0-auc:0.90470
# [341]	validation_0-auc:0.90462
# [342]	validation_0-auc:0.90461
# [343]	validation_0-auc:0.90464
# [344]	validation_0-auc:0.90461
# [345]	validation_0-auc:0.90458
# [346]	validation_0-auc:0.90455
# [347]	validation_0-auc:0.90450
# [348]	validation_0-auc:0.90450
# [349]	validation_0-auc:0.90452
# [350]	validation_0-auc:0.90452
# [351]	validation_0-auc:0.90444
# [352]	validation_0-auc:0.90438
# [353]	validation_0-auc:0.90440
# [354]	validation_0-auc:0.90437
# [355]	validation_0-auc:0.90434
# [356]	validation_0-auc:0.90425
# [357]	validation_0-auc:0.90418
# [358]	validation_0-auc:0.90416
# [359]	validation_0-auc:0.90424
# [360]	validation_0-auc:0.90422
# [361]	validation_0-auc:0.90424
# [362]	validation_0-auc:0.90425
# [363]	validation_0-auc:0.90422
# [364]	validation_0-auc:0.90423
# [365]	validation_0-auc:0.90430
# [366]	validation_0-auc:0.90423
# [367]	validation_0-auc:0.90421
# [368]	validation_0-auc:0.90421
# [369]	validation_0-auc:0.90420
# [370]	validation_0-auc:0.90413
# [371]	validation_0-auc:0.90410
# [372]	validation_0-auc:0.90400
# [373]	validation_0-auc:0.90396
# [374]	validation_0-auc:0.90406
# [375]	validation_0-auc:0.90412
# [376]	validation_0-auc:0.90412
# [377]	validation_0-auc:0.90408
# [378]	validation_0-auc:0.90404
# [379]	validation_0-auc:0.90406
# [380]	validation_0-auc:0.90399
# [381]	validation_0-auc:0.90397
# [382]	validation_0-auc:0.90394
# [383]	validation_0-auc:0.90394
# [384]	validation_0-auc:0.90393
# [385]	validation_0-auc:0.90384
# [386]	validation_0-auc:0.90384
# [387]	validation_0-auc:0.90385
# [388]	validation_0-auc:0.90383
# [389]	validation_0-auc:0.90375
# [390]	validation_0-auc:0.90367
# [391]	validation_0-auc:0.90363
# [392]	validation_0-auc:0.90359
# [393]	validation_0-auc:0.90357
# [394]	validation_0-auc:0.90352
# [395]	validation_0-auc:0.90349
# [396]	validation_0-auc:0.90347
# [397]	validation_0-auc:0.90341
# [398]	validation_0-auc:0.90335
# [399]	validation_0-auc:0.90334
# [400]	validation_0-auc:0.90330
# [401]	validation_0-auc:0.90329
# [402]	validation_0-auc:0.90322
# [403]	validation_0-auc:0.90324
# [404]	validation_0-auc:0.90325
# [405]	validation_0-auc:0.90321
# [406]	validation_0-auc:0.90306
# [407]	validation_0-auc:0.90304
# [408]	validation_0-auc:0.90302
# [409]	validation_0-auc:0.90300
# [410]	validation_0-auc:0.90298
# [411]	validation_0-auc:0.90297
# [412]	validation_0-auc:0.90301
# [413]	validation_0-auc:0.90296
# [414]	validation_0-auc:0.90300
# [415]	validation_0-auc:0.90302
# [416]	validation_0-auc:0.90303
# [417]	validation_0-auc:0.90301
# [418]	validation_0-auc:0.90299
# [419]	validation_0-auc:0.90297
# [420]	validation_0-auc:0.90304
# [421]	validation_0-auc:0.90307
# [422]	validation_0-auc:0.90306
# [423]	validation_0-auc:0.90300
# [424]	validation_0-auc:0.90301
# [425]	validation_0-auc:0.90297
# [426]	validation_0-auc:0.90298
# [427]	validation_0-auc:0.90298
# [428]	validation_0-auc:0.90294
# [429]	validation_0-auc:0.90300
# [430]	validation_0-auc:0.90302
# [431]	validation_0-auc:0.90300
# [432]	validation_0-auc:0.90298
# [433]	validation_0-auc:0.90294
# [434]	validation_0-auc:0.90290
# [435]	validation_0-auc:0.90286
# [436]	validation_0-auc:0.90286
# [437]	validation_0-auc:0.90288
# [438]	validation_0-auc:0.90280
# [439]	validation_0-auc:0.90269
# [440]	validation_0-auc:0.90263
# [441]	validation_0-auc:0.90262
# [442]	validation_0-auc:0.90260
# [443]	validation_0-auc:0.90253
# [444]	validation_0-auc:0.90249
# [445]	validation_0-auc:0.90249
# [446]	validation_0-auc:0.90246
# [447]	validation_0-auc:0.90241
# [448]	validation_0-auc:0.90237
# [449]	validation_0-auc:0.90229
# [450]	validation_0-auc:0.90220
# [451]	validation_0-auc:0.90223
# [452]	validation_0-auc:0.90225
# [453]	validation_0-auc:0.90225
# [454]	validation_0-auc:0.90217
# [455]	validation_0-auc:0.90215
# [456]	validation_0-auc:0.90213
# [457]	validation_0-auc:0.90212
# [458]	validation_0-auc:0.90208
# [459]	validation_0-auc:0.90201
# [460]	validation_0-auc:0.90197
# [461]	validation_0-auc:0.90187
# [462]	validation_0-auc:0.90182
# [463]	validation_0-auc:0.90177
# [464]	validation_0-auc:0.90184
# [465]	validation_0-auc:0.90183
# [466]	validation_0-auc:0.90184
# [467]	validation_0-auc:0.90185
# [468]	validation_0-auc:0.90182
# [469]	validation_0-auc:0.90184
# [470]	validation_0-auc:0.90183
# [471]	validation_0-auc:0.90180
# [472]	validation_0-auc:0.90183
# [473]	validation_0-auc:0.90179
# [474]	validation_0-auc:0.90177
# [475]	validation_0-auc:0.90173
# [476]	validation_0-auc:0.90163
# [477]	validation_0-auc:0.90163
# [478]	validation_0-auc:0.90155
# [479]	validation_0-auc:0.90143
# [480]	validation_0-auc:0.90138
# [481]	validation_0-auc:0.90135
# [482]	validation_0-auc:0.90139
# [483]	validation_0-auc:0.90139
# [484]	validation_0-auc:0.90132
# [485]	validation_0-auc:0.90122
# [486]	validation_0-auc:0.90112
# [487]	validation_0-auc:0.90103
# [488]	validation_0-auc:0.90098
# [489]	validation_0-auc:0.90091
# [490]	validation_0-auc:0.90080
# [491]	validation_0-auc:0.90070
# [492]	validation_0-auc:0.90064
# [493]	validation_0-auc:0.90057
# [494]	validation_0-auc:0.90059
# [495]	validation_0-auc:0.90057
# [496]	validation_0-auc:0.90060
# [497]	validation_0-auc:0.90055
# [498]	validation_0-auc:0.90049
# [499]	validation_0-auc:0.90038
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from imblearn.metrics import geometric_mean_score
import matplotlib.pyplot as plt

y_pred = model.predict(X_val)

print("\nClassification Report:")
print(classification_report(y_val, y_pred, digits=4))

ConfusionMatrixDisplay.from_predictions(y_val, y_pred, display_labels=["Not Fraud", "Fraud"], cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

gmean = geometric_mean_score(y_val, y_pred)
print(f"Geometric Mean Score: {gmean:.4f}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9877    0.9203    0.9528     38500
#            1     0.2565    0.7060    0.3763      1500
#
#     accuracy                         0.9123     40000
#    macro avg     0.6221    0.8131    0.6646     40000
# weighted avg     0.9603    0.9123    0.9312     40000
# Geometric Mean Score: 0.8061

# %% [markdown]
# Feature Importance

# %%
# plot feature importance from xgboost model
import matplotlib.pyplot as plt
import xgboost

fig, ax = plt.subplots(figsize=(10, 10))
xgboost.plot_importance(model, importance_type="weight", ax=ax)
plt.show()

# %%
import joblib

model.save_model("/content/drive/MyDrive/FYP_model_assets/xgb_geolocation_fraud_model.bst")
joblib.dump(ordinal_encoder, "/content/drive/MyDrive/FYP_model_assets/geoloc_encoder.pkl")
joblib.dump(num_imputer, "/content/drive/MyDrive/FYP_model_assets/geoloc_imputer.pkl")

# Save feature names to ensure Triton/microservice aligns
import json
with open("geolocation_fraud_feature_order.json", "w") as f:
    json.dump(list(X.columns), f)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [22:46:11] WARNING: /workspace/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
df = pd.read_csv('/content/drive/My Drive/FYP_model_assets/fraud_transactions.csv')

# %%
df
# Out:
#     transaction_id timestamp   amount currency transaction_type country  \
# 0           115223   10:41.0   205.10      GBP         TRANSFER      SA
# 1            96679   49:20.6   104.63      GBP       WITHDRAWAL      BA
# 2            58395   47:36.1   191.14      JPY         PURCHASE      CI
# 3           143302   25:46.2   438.50      EUR         PURCHASE      ST
# 4             4561   26:57.2    42.35      EUR         TRANSFER      JM
# 5           180598   57:53.4   241.97      EUR         PURCHASE      MT
# 6           160190   38:09.4   193.60      EUR       WITHDRAWAL      MH
# 7            72704   33:14.8   192.87      GBP         TRANSFER      KM
# 8            30987   18:57.6    67.04      JPY       WITHDRAWAL      TM
# 9            96658   00:18.0    82.27      USD       WITHDRAWAL      MT
# 10          144789   23:07.4   108.04      GBP         PURCHASE      KR
# 11          150616   20:19.5   597.26      EUR       WITHDRAWAL      RW
# 12          195755   57:35.4  1061.33      EUR         PURCHASE      NZ
# 13           26611   47:27.1     0.52      JPY       WITHDRAWAL      QA
# 14           39587   13:20.2   532.38      EUR         PURCHASE      RW
# 15          101176   25:42.3   283.37      EUR         TRANSFER      BS
# 16            1418   54:35.6     7.59      USD       WITHDRAWAL      ID
# 17          154582   48:12.6   346.41      JPY         PURCHASE      LS
# 18          194636   09:32.6  1050.17      GBP       WITHDRAWAL      RS
# 19          112416   54:50.6   615.74      GBP       WITHDRAWAL      SL
# 20          188932   00:26.2   508.70      EUR         PURCHASE      TW
# 21          170297   59:35.3   346.99      JPY       WITHDRAWAL      GY
# 22          157156   10:56.0   664.82      USD       WITHDRAWAL      MC
# 23          179936   32:37.6   420.35      USD       WITHDRAWAL      BO
# 24          187952   18:03.3   136.55      USD         PURCHASE      LI
# 25          100329   21:03.1    63.93      GBP       WITHDRAWAL      PS
# 26          123006   00:40.4    62.28      EUR       WITHDRAWAL      TL
# 27           52788   14:02.4    29.65      JPY       WITHDRAWAL      GA
# 28           61505   59:09.0  1077.96      JPY         PURCHASE      LT
# 29          141683   24:50.7   208.36      USD         PURCHASE      MV
# 30           82875   48:25.4    48.40      EUR         PURCHASE      GN
# 31          178224   49:59.8   143.63      JPY       WITHDRAWAL      SG
# 32          131850   58:55.6    19.68      EUR         PURCHASE      TJ
# 33          169919   20:57.2   152.03      EUR         PURCHASE      IR
# 34          164395   36:51.3   113.37      GBP       WITHDRAWAL      GD
# 35          110140   47:22.6   609.83      GBP         TRANSFER      GH
# 36           15603   56:34.1   408.58      JPY         PURCHASE      MN
# 37          178378   35:25.9   108.22      GBP         PURCHASE      PH
# 38           73256   20:23.5  1335.99      JPY       WITHDRAWAL      XX
# 39          140772   00:58.7    67.77      JPY       WITHDRAWAL      GN
# 40           22060   07:32.7   199.33      USD         PURCHASE      SD
# 41          153227   30:15.0   200.27      USD       WITHDRAWAL      FJ
# 42           32004   19:40.7    77.69      USD       WITHDRAWAL      MX
# 43           47683   23:54.9   115.39      JPY       WITHDRAWAL      GD
# 44          121482   10:52.1   159.27      EUR       WITHDRAWAL      JO
# 45          173067   48:13.7    58.09      JPY         TRANSFER      BR
# 46            4233   57:14.3   204.54      EUR       WITHDRAWAL     NaN
# 47          122629   54:19.2    28.94      GBP         PURCHASE      NG
# 48          176714   19:15.0    50.10      EUR         TRANSFER      GD
# 49          111967   36:37.2   674.50      GBP         PURCHASE      AE
# 50           57858   21:45.4   322.88      EUR         PURCHASE      UZ
# 51          125600   20:14.5   131.33      GBP       WITHDRAWAL      BD
# 52          117136   44:37.4   376.68      GBP         TRANSFER      LI
# 53          198633   24:55.4   172.55      USD         PURCHASE      HN
# 54           20497   40:47.2    21.46      JPY         PURCHASE      TZ
# 55           76413   45:54.7   268.91      JPY         PURCHASE      EG
# 56           23240   11:47.4   135.12      EUR         PURCHASE      RO
# 57           39004   17:00.2    55.19      USD         TRANSFER      NZ
# 58          145641   28:11.2   317.12      USD         PURCHASE      XX
#
#                     city   latitude   longitude       ip_address  ...  \
# 0            Leslieshire   5.921392  -41.794455    203.223.67.83  ...
# 1               Adamtown  15.473220         NaN    81.157.109.58  ...
# 2            South Carol  52.123934   92.665651    45.208.77.195  ...
# 3             Carmenside   8.078260  -97.733702   167.181.31.106  ...
# 4       Lake Michaelfort        NaN  -96.494233    99.221.18.251  ...
# 5     West Stephanieside  36.093600         NaN    207.110.10.22  ...
# 6     Port Kimberlyshire  83.816264   12.943654   202.244.225.94  ...
# 7           Wilkinsonton -51.203019  132.307657    215.146.232.1  ...
# 8             Stevenland   5.931396  158.624377   144.52.227.101  ...
# 9           Jameschester -50.170784  -77.806130  144.151.117.132  ...
# 10             West Jill -54.776758 -151.528520   182.46.101.219  ...
# 11            Brandibury -57.994654         NaN  170.151.211.206  ...
# 12           Austinhaven  60.608926  159.610270    141.173.254.5  ...
# 13          North Johnny -73.342852  171.307485   195.215.118.89  ...
# 14        Lake Jamesstad -76.514695         NaN      32.9.99.178  ...
# 15           Rowlandberg -33.100354         NaN    39.45.241.167  ...
# 16          Campbellstad -64.994412   53.296013   218.28.147.217  ...
# 17             Reyesfort -15.253572         NaN     1.217.45.229  ...
# 18    East Frederickport  31.174338 -168.979954     8.109.42.151  ...
# 19            Millerfurt  81.050743         NaN     72.24.112.61  ...
# 20            Michaelton   4.483110  168.481232   172.247.45.165  ...
# 21      Port Robertmouth -46.961375         NaN   91.192.191.112  ...
# 22         Reynoldsshire        NaN -148.806558     22.132.7.161  ...
# 23         West Kathleen  86.653652  -28.294937   104.167.85.109  ...
# 24           North Stacy  84.274154    2.597379   183.196.47.153  ...
# 25        New Josephside        NaN  -24.452913   141.172.123.75  ...
# 26             West Mike        NaN -155.314425    93.188.14.158  ...
# 27         Mcdonaldmouth -14.838177 -133.190317     208.98.173.4  ...
# 28         Port Lisabury -39.829118 -152.162346   132.39.229.130  ...
# 29            East Tanya -16.872216 -174.570420     128.48.80.52  ...
# 30       East Danielview  81.105689   -7.453592     139.80.59.66  ...
# 31               Coxside -17.923808  -40.437569    203.110.94.69  ...
# 32         Lake Courtney  61.755616   97.292489     35.41.95.250  ...
# 33         New Tammyview   6.507636   34.524365    204.46.117.43  ...
# 34           West Jordan -44.380884  169.879884   112.191.205.99  ...
# 35          East Timothy -22.761212 -155.168996   221.159.198.10  ...
# 36         Lake Jonathan   0.161541  -16.431761   128.56.149.229  ...
# 37             West Tina  86.712722   96.915639    198.33.216.25  ...
# 38             West Tara  38.361418 -131.716044   87.183.108.219  ...
# 39        West Juliaview        NaN -125.032815    59.181.169.28  ...
# 40         New Dylanfort  75.627500   50.429203   32.227.204.243  ...
# 41              Earltown -41.194016 -130.657427  196.142.230.153  ...
# 42  North Christinamouth -10.470706  -13.382298  156.243.173.179  ...
# 43              New Sara  60.889528  -42.312838    192.153.68.82  ...
# 44               Leeport -30.996621  -33.415623   197.215.71.150  ...
# 45        Barbaraborough        NaN  -79.069963    217.211.49.77  ...
# 46      New Richardmouth        NaN   14.005326    172.13.45.138  ...
# 47          Lake Matthew -14.051358         NaN    96.109.60.176  ...
# 48         Griffithville        NaN  -96.268072    194.237.93.97  ...
# 49         Jenniferville  18.178624  -80.231677   207.207.234.93  ...
# 50            New Rachel  34.366656         NaN  155.134.109.199  ...
# 51            Traceystad   1.806051   38.551669   198.96.143.249  ...
# 52            Priceburgh -50.117574 -166.958312    143.22.20.108  ...
# 53      North Paulamouth        NaN  152.829238  208.120.246.218  ...
# 54             West Jack        NaN -132.926777     73.40.166.38  ...
# 55       Christopherstad -68.320790  -11.655911    83.236.202.76  ...
# 56          Andersonside -89.635563         NaN   201.15.248.145  ...
# 57           Walkermouth        NaN  174.380685  199.223.106.173  ...
# 58          Websterburgh  50.930486   36.854589   222.49.206.246  ...
#
#    transactions_last_7d  time_since_last_login login_attempts_last_24h  \
# 0                     6                  151.1                       6
# 1                     5                   76.2                       0
# 2                     1                   79.4                       6
# 3                     6                  155.3                       2
# 4                     6                  146.7                       3
# 5                     9                  163.3                       4
# 6                     8                  140.7                       4
# 7                     4                   52.3                       3
# 8                     8                   72.3                       6
# 9                     5                  139.9                       6
# 10                    5                   76.1                       2
# 11                   11                   18.0                       0
# 12                    6                   52.3                       1
# 13                    5                    7.9                       0
# 14                    4                  123.2                       3
# 15                    5                   36.2                       4
# 16                    3                  117.7                       2
# 17                    4                   99.4                       2
# 18                    6                   33.2                       6
# 19                    5                    2.4                       4
# 20                    2                   26.4                       1
# 21                    6                   16.1                       1
# 22                    7                  109.2                       6
# 23                    6                  161.0                       1
# 24                    8                   98.8                       4
# 25                    7                  166.8                       4
# 26                    6                   12.7                       4
# 27                    5                   90.0                       5
# 28                   10                   12.5                       2
# 29                    4                   86.8                       1
# 30                    8                  123.8                       1
# 31                    7                   64.9                       2
# 32                    9                    1.5                       3
# 33                    6                   72.5                       5
# 34                    2                   45.7                       4
# 35                    5                   52.7                       1
# 36                    8                  121.8                       3
# 37                    5                  146.4                       5
# 38                    5                  122.8                       6
# 39                    4                  143.8                       3
# 40                    7                   73.5                       4
# 41                    4                   68.4                       5
# 42                    5                   24.2                       3
# 43                    9                  135.0                       2
# 44                    3                   91.5                       5
# 45                    8                  140.2                       6
# 46                    5                  107.2                       5
# 47                    7                  150.8                       5
# 48                    6                   20.2                       3
# 49                    5                   29.5                       1
# 50                    9                  160.0                       0
# 51                    7                    5.3                       0
# 52                    4                   35.9                       2
# 53                    5                   43.6                       5
# 54                    8                  157.8                       2
# 55                    6                   94.8                       3
# 56                    8                   49.2                       1
# 57                    3                   11.7                       3
# 58                    9                  141.8                       3
#
#    is_new_device vpn_usage proxy_usage ip_risk_score    ASN  \
# 0              0         0           1            37  41040
# 1              0         0           0            68  64260
# 2              0         0           0            39  51540
# 3              0         0           0            64  56676
# 4              1         0           0            58  95436
# 5              1         0           0            22  73513
# 6              0         1           1           100   7987
# 7              0         0           0            69  71909
# 8              1         0           0            95  45927
# 9              1         1           0            58   6996
# 10             0         0           0            29  99879
# 11             0         1           1            94  53210
# 12             1         0           0            60  20398
# 13             1         0           0           100  48598
# 14             0         0           0           100  73330
# 15             1         0           0            23  45553
# 16             0         0           1            67  50668
# 17             1         0           0            99  48151
# 18             1         0           1            82  48180
# 19             0         1           1            84  92812
# 20             0         0           1            70  85261
# 21             0         0           0            44  74244
# 22             1         1           0            81  57155
# 23             1         0           0           100  38672
# 24             1         1           0            68  48000
# 25             0         0           0            46  59101
# 26             1         1           0            65  46337
# 27             0         1           0            89  81151
# 28             1         0           0            29  79788
# 29             0         0           0            72  10862
# 30             0         1           0            50  54323
# 31             0         1           0            76  12282
# 32             0         1           0            47  95908
# 33             0         0           0            31  40055
# 34             1         0           0            37  19800
# 35             0         1           1            71  12534
# 36             0         1           0            48  21053
# 37             1         1           0            91  58149
# 38             0         0           0            66  41301
# 39             0         0           0            79  35614
# 40             0         0           0            24  58279
# 41             0         1           1            57  76631
# 42             1         1           0            73  23057
# 43             0         0           1            53  61609
# 44             1         0           0            27  53185
# 45             1         0           0            36  37506
# 46             1         0           0            51   2082
# 47             1         0           0            70  24395
# 48             0         1           1            85  53072
# 49             1         0           1            58  29813
# 50             0         1           0           100  64283
# 51             1         0           1           100  74190
# 52             0         0           0            45  46136
# 53             0         0           0            28  44027
# 54             0         1           0           100  52397
# 55             1         0           0            33  18418
# 56             1         1           0            74  46748
# 57             1         1           0            83  69597
# 58             1         0           0             8  94116
#
#                                ISP  is_fraud
# 0          Hill, Phillips and Mata         1
# 1                       Ponce-Cole         1
# 2                      Reed-Parker         1
# 3                    Peters-Rogers         1
# 4         Collins, Pope and Fowler         1
# 5   Whitaker, Hernandez and Carter         1
# 6                       Cole-Allen         1
# 7                Franklin and Sons         1
# 8                         Hart PLC         1
# 9                    Jones-Coleman         1
# 10                    James-Miller         1
# 11    Walker, Zuniga and Rodriguez         1
# 12                   Mills-Johnson         1
# 13                      Howard Ltd         1
# 14                  Preston-Bryant         1
# 15       Martin, Barron and Horton         1
# 16      Pena, Simmons and Martinez         1
# 17                Wright-Hernandez         1
# 18          Smith, Moore and Myers         1
# 19             Bass, May and Woods         1
# 20                    Clark-Rogers         1
# 21      Smith, Swanson and Vasquez         1
# 22                   Hernandez Ltd         1
# 23                      Flores Inc         1
# 24                     Diaz-Wilcox         1
# 25                   Sims and Sons         1
# 26       Chase, Peterson and Allen         1
# 27       Douglas, Bell and Hampton         1
# 28                   Fuller-Glover         1
# 29                     Long-Pierce         1
# 30                 Daniel-Sandoval         1
# 31       Snyder, Mora and Saunders         1
# 32      Dillon, Warren and Mueller         1
# 33    Hernandez, Taylor and Torres         1
# 34                  Taylor-Solomon         1
# 35                  Hopkins-Murphy         1
# 36        Murray, Garcia and Mason         1
# 37                   Rogers-Farley         1
# 38           Vega, Bishop and Hill         1
# 39                       Cross Inc         1
# 40                     Price-Davis         1
# 41                     Simmons Ltd         1
# 42      Hampton, Moon and Mitchell         1
# 43                      Norton Inc         1
# 44                   Taylor-Zavala         1
# 45          Turner, Cox and Norris         1
# 46                   Gonzales-Hays         1
# 47                   Jones-Sherman         1
# 48         Benson, Jones and Smith         1
# 49                 Walter-Davidson         1
# 50                     Dixon-Jones         1
# 51                       Petty Inc         1
# 52       Callahan, Blake and Wells         1
# 53                       Rush-Boyd         1
# 54                     Morales LLC         1
# 55                     Jones-Scott         1
# 56                Henderson-Thomas         1
# 57         Williams, Lane and Hill         1
# 58                  Douglas-Warren         1
#
# [59 rows x 28 columns]
